# %%
from parse_and_load_data import normalize_json_file

# %%
result = normalize_json_file()
# Out:
# 2025-07-18 15:01:57,234 - INFO - parse_and_load_data - Successfully read data
# 2025-07-18 15:01:57,305 - INFO - execute_sql_query - Successfully connected to the database.
# 2025-07-18 15:01:57,322 - INFO - execute_sql_query - Data successfully loaded into the 'continent' table.
# 2025-07-18 15:01:57,497 - INFO - execute_sql_query - Successfully connected to the database.
# 2025-07-18 15:01:57,511 - INFO - execute_sql_query - Data successfully loaded into the 'country' table.
# 2025-07-18 15:01:57,571 - INFO - execute_sql_query - Successfully connected to the database.
# 2025-07-18 15:01:57,583 - INFO - execute_sql_query - Data successfully loaded into the 'city' table.
# 2025-07-18 15:01:57,645 - INFO - execute_sql_query - Successfully connected to the database.
# 2025-07-18 15:01:57,650 - INFO - execute_sql_query - Data successfully loaded into the 'city' table.
# 2025-07-18 15:01:57,714 - INFO - execute_sql_query - Successfully connected to the database.
# ...
